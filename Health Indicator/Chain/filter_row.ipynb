# %% [markdown]
# 데이터의 필요없는 부분을 제거하고 내보내는 소스

# %%
# 라이브러리 가져오기
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
# 데이터 불러오기
data = pd.read_csv("C:/Users/PC/Desktop/RUL/11min.csv", error_bad_lines=False, skiprows=[0,1,2,3,4,5,6,7,8], nrows=330000000, header=None)

# %%
# 확인
print(data.tail(3))
# Out:
# 0         1   2
# 33030141  660.60282 -0.189477 NaN
# 33030142  660.60284 -0.169675 NaN
# 33030143  660.60286 -0.173582 NaN

# %%
# 데이터를 앞뒤 1분을 제외하고 가공
# 11분 일경우 3000000:30000000
# 10분 일경우 3000000:27000000
# 가공된 데이터를 넘파이 배열로 변환후에 정규화 및 그래프 출력
first_filter_data = np.array(data.iloc[3000000:27000000, 1:2].values, np.float64)
first_filter_data =StandardScaler().fit_transform(first_filter_data)
first_filter_data = np.ravel(first_filter_data, order='C')
plt.plot(first_filter_data)

# %%
# 데이터 저장하기
output_data = pd.DataFrame(first_filter_data)
output_data.to_csv("C:/Users/PC/Desktop/RUL/Lab008.txt", index=False, header=None)
